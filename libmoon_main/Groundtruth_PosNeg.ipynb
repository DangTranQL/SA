# %%
import numpy as np
import matplotlib.pyplot as plt


file_path = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_0_1.npy"
file_path_2 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_0_2.npy"
file_path_3 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_0_3.npy"
file_path_4 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_0_4.npy"
file_path_5 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_0_5.npy"
file_path_6 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_1_2.npy"
file_path_7 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_1_3.npy"
file_path_8 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_1_4.npy"
file_path_9 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_1_5.npy"
file_path_10 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_2_3.npy"
file_path_11 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_2_4.npy"
file_path_12 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_2_5.npy"
file_path_13 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_3_4.npy"
file_path_14 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_3_5.npy"
file_path_15 = "/home/m3-learning/Downloads/PosNegFbGridSearchData_renamed/paretoset_SensPair_4_5.npy"
pairs_0_1 = np.load(file_path)
pairs_0_2 = np.load(file_path_2)
pairs_0_3 = np.load(file_path_3)
pairs_0_4 = np.load(file_path_4)
pairs_0_5 = np.load(file_path_5)
pairs_1_2 = np.load(file_path_6)
pairs_1_3 = np.load(file_path_7)
pairs_1_4 = np.load(file_path_8)
pairs_1_5 = np.load(file_path_9)
pairs_2_3 = np.load(file_path_10)
pairs_2_4 = np.load(file_path_11)
pairs_2_5 = np.load(file_path_12)
pairs_3_4 = np.load(file_path_13)
pairs_3_5 = np.load(file_path_14)
pairs_4_5 = np.load(file_path_15)

# %%
plt.figure(figsize=(8,6))
plt.scatter(pairs_0_1[:,0], pairs_0_1[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{\beta_x,x_{ss}}$')  
plt.ylabel(r'$S_{\beta_x,y_{ss}}$')  
plt.title(r'Grid-Search Pareto Front for $S_{\beta_x,x_{ss}}$ vs $S_{\beta_x,y_{ss}}$')
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_0_2[:,0], pairs_0_2[:,1], s=5, alpha=0.6)
plt.xlabel("Value 1")
plt.ylabel("Value 2")
plt.title("Pair Plot - 0_2")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_0_3[:,0], pairs_0_3[:,1], s=5, alpha=0.6)
plt.xlabel("Value 1")
plt.ylabel("Value 2")
plt.title("Pair Plot - 0_3")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_0_4[:,0], pairs_0_4[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{\beta_x,x_{ss}}$')
plt.ylabel(r'$S_{\beta_x,n}$')
plt.title(r"Grid-Search Pareto Front for $S_{\beta_x,x_{ss}}$ vs $S_{n,x_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(pairs_0_5[:,0], pairs_0_5[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{\beta_x,x_{ss}}$')
plt.ylabel(r'$S_{n,y_{ss}}$')
plt.title(r'Grid-search Pareto Front for $S_{\beta_x,x_{ss}}$ vs $S_{n,y_{ss}}$')
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_1_2[:,0], pairs_1_2[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{\beta_x,y_{ss}}$')
plt.ylabel(r'$S_{\beta_y,x_{ss}}$')
plt.title(r'Grid-search Pareto Front for $S_{\beta_x,y_{ss}}$ vs $S_{\beta_y,x_{ss}}$')
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(pairs_1_3[:,0], pairs_1_3[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{\beta_x,y_{ss}}$')
plt.ylabel(r'$S_{\beta_y,y_{ss}}$')
plt.title(r'Grid-search Pareto Front for $S_{\beta_x,y_{ss}}$ vs $S_{\beta_y,y_{ss}}$')
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(pairs_1_4[:,0], pairs_1_4[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_x,y_{ss}}$")
plt.ylabel(r"$S_{n,x_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_x,y_{ss}}$ vs $S_{n,x_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_1_5[:,0], pairs_1_5[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_x,y_{ss}}$")
plt.ylabel(r"$S_{n,y_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_x,y_{ss}}$ vs $S_{n,y_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(pairs_2_3[:,0], pairs_2_3[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_y,x_{ss}}$")
plt.ylabel(r"$S_{\beta_y,y_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_y,x_{ss}}$ vs $S_{\beta_y,y_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_2_4[:,0], pairs_2_4[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_y,x_{ss}}$")
plt.ylabel(r"$S_{n,x_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_y,x_{ss}}$ vs $S_{n,x_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_2_5[:,0], pairs_2_5[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_y,x_{ss}}$")
plt.ylabel(r"$S_{n,y_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_y,x_{ss}}$ vs $S_{n,y_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_3_4[:,0], pairs_3_4[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_y,y_{ss}}$")
plt.ylabel(r"$S_{n,x_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_y,y_{ss}}$ vs $S_{n,x_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_3_5[:,0], pairs_3_5[:,1], s=5, alpha=0.6)
plt.xlabel(r"$S_{\beta_y,y_{ss}}$")
plt.ylabel(r"$S_{n,y_{ss}}$")
plt.title(r"Grid-search Pareto Front for $S_{\beta_y,y_{ss}}$ vs $S_{n,y_{ss}}$")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(pairs_4_5[:,0], pairs_4_5[:,1], s=5, alpha=0.6)
plt.xlabel(r'$S_{n,x_{ss}}$')
plt.ylabel(r'$S_{n,y_{ss}}$')
plt.title(r"Grid-search Pareto Front for $S_{n,x_{ss}}$ vs $S_{n,y_{ss}}$")
plt.grid(False)
plt.show()
